# %% [markdown]
# Contents:
# 1. Basic object types
# 2. Strings
# 3. Sequence Types
# 4. Variables and Assignments
# 5. Conditional Statements
# 6. For loops and while loops
# 7. Iterables

# %%
#Basic Object types

#Built-in isinstance function
print(isinstance('13', str))
print(isinstance(13, int))
print(isinstance(13.9, int))
print(isinstance(13.9, float))
print(isinstance(True, bool))

#Type function to check the type of an object
print(type(13))
print(type(13.9))
print(type('13'))
print(type(False))

#math module
import math
print(math.sqrt(13))
print(math.log10(100))

print("Never compare if two floating point numbers are equal since that will never be the case. Refer below:")
print(('(0.1+0.1+0.1)-0.3)==0 is: '))
print(((0.1+0.1+0.1)-0.3)==0)
print("As seen above, two floats are never equal. Hence, we should only check if two floats are approximately equal to each other")
print('math.isclose(0.1+0.1+0.1-0.3, 0., abs_tol=1e-9) is:')
print(math.isclose(0.1+0.1+0.1-0.3, 0., abs_tol=1e-9))

#Boolean objects
print("Boolean objects, True and False, formally belong to the int type in addition to bool. True is associated with 1 and False with 0")
print(int(True), int(False))
print(isinstance(True, int))

#None Type
print("the None Type has only one object: None which is used to represent nothing. To check if an object belongs to None Type, simply check if the object is None using the 'is' operator.")
x=22
print(x is None)
print(x is not None)
# Out:
# True
# True
# False
# True
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# 3.605551275463989
# 2.0
# Never compare if two floating point numbers are equal since that will never be the case. Refer below:
# (0.1+0.1+0.1)-0.3)==0 is:
# False
# As seen above, two floats are never equal. Hence, we should only check if two floats are approximately equal to each other
# math.isclose(0.1+0.1+0.1-0.3, 0., abs_tol=1e-9) is:
# True
# Boolean objects, True and False, formally belong to the int type in addition to bool. True is associated with 1 and False with 0
# 1 0
# True
# the None Type has only one object: None which is used to represent nothing. To check if an object belongs to None Type, simply check if the object is None using the 'is' operator.
# False
# True

# %%
#Strings
print("String can be formed using ' \" or ''' or  \"\"\" .")
str1='This is an example of string using single quote'
str2="This is an example of string using double quotes"
str3='''This is an example of string using 3-single quotes'''
str4="""THis is an example of string using 3-double quotes"""
print(str1, str2, str3, str4)
print('''Using triple quotes allows us to write block strings without adding \\n to create new lines.
Simply writing new lines within the triple quotes will allow us to create strings 
with 
multiple lines.''')
print('To do the same in single or double quoted strings, \\n character has to \n be \n used.')
print("Strings are immutable meaning that once a string is formed, it cannot be changed without creating a new string.")

#Formatting Strings
print("\n\nUsing the format method for String formatting...")
print("{name} is {age} years old.".format(name="bruce", age=21))
print("{item:>9} is not available".format(item="stew"))
print("\nUsing f-strings")
a=10
b=11
c=f'''Here we see the use of f-strings. value stored in variable a is {a} and value stored in variable b is {b} their sum is {a+b}'''
print(c)
# Out:
# String can be formed using ' " or ''' or  """ .
# This is an example of string using single quote This is an example of string using double quotes This is an example of string using 3-single quotes THis is an example of string using 3-double quotes
# Using triple quotes allows us to write block strings without adding \n to create new lines.
# Simply writing new lines within the triple quotes will allow us to create strings
# with
# multiple lines.
# To do the same in single or double quoted strings, \n character has to
#  be
#  used.
# Strings are immutable meaning that once a string is formed, it cannot be changed without creating a new string.
#
#
# Using the format method for String formatting...
# bruce is 21 years old.
#      stew is not available
#
# Using f-strings
# Here we see the use of f-strings. value stored in variable a is 10 and value stored in variable b is 11 their sum is 21

# %%
#Lists
print("Lists are Python objects that store sequence of objects of different types. Lists are mutable meaning that its contents can be later updated.")
print("An empty list can be constructed as below:")
a=[]
print(f'Here is an empty List defined by a=[] and will be displayed as: {a}')
b=[123,'123',['aaa','bbb'], True, 12.09]
print(f'''A single list can store objects of different types. Here, b is a list containing objects of different types, 
      including another list: {b}''')
c=[2>3, 'acb'.capitalize(), int(17.9)]
print(f''' \nPython will simplify any expressions, variables in the list constructor and store the result in the List
Here we have an example of list defined as c=[2>3, 'acb'.capitalize(), int(17.9)]. The resultant list is: {c}''')
str1='skjdh,xkjashdlanf'
list1=list(str1)
print(f'''\nWe can use the built-in list() type to convert any other sequence into a list.
Here is an example as we have a string {str1} and a list created using the list() type as follows:
list1=list(str1)
The final result is as follows: {list1}''')
x=[1,2,4,1,2,45,9]
print(f"""\nList Mutation: Below we will look at how we can mutate a list after it has been created.
We have a list x as {x}""")
x[3]=23
print(f'''\nWe are updating the 4th element in x with 23 using the statement x[3]=23. Now, the list is updated as {x}''')
x[3:6]=[20,21,22]
print(f'''we can also update a sequence of elements in x with the statement x[3:6]=[20,21,22]. Now, the list x is {x}''')
print('\nappend, extend, pop and remove.\nWe can also use the built-in list functions append and extend to add a single element or multiple at the end of the list.')
x.append('moo')
print(f'\nWe use the append function as x.append("moo"). \nThe resultant list x is {x}')
x.extend([1,True,False,'123asd'])
print(f'\nWe use the extend function as x.extend([1,True,False,"123asd"]). \nThe resultant list x is {x}')
x.pop(2)
print('Similary we can use the pop and remove functions to remove elements from a list.\npop funnction will remove an element at the index passed into it as argument and will return the popped element.\nx.pop(2) will pop the element at index 2')
print('the resultant list is {}'.format(x))
x.pop()
print('If no value is passed in the pop function, it will remove the last element from the list. x.pop()')
print(f'''The resultant list is {x}
Remove function will remove the first occurence of the element passed as a function.
It can be used as x.remove(1) and the resultant list is: ''')
x.remove(1)
print(x)
# Out:
# Lists are Python objects that store sequence of objects of different types. Lists are mutable meaning that its contents can be later updated.
# An empty list can be constructed as below:
# Here is an empty List defined by a=[] and will be displayed as: []
# A single list can store objects of different types. Here, b is a list containing objects of different types,
#       including another list: [123, '123', ['aaa', 'bbb'], True, 12.09]
#
# Python will simplify any expressions, variables in the list constructor and store the result in the List
# Here we have an example of list defined as c=[2>3, 'acb'.capitalize(), int(17.9)]. The resultant list is: [False, 'Acb', 17]
#
# We can use the built-in list() type to convert any other sequence into a list.
# Here is an example as we have a string skjdh,xkjashdlanf and a list created using the list() type as follows:
# list1=list(str1)
# ...

# %%
a=[None]
k=[-1,True,"yes"]
print(k)
k.extend([float(9), complex(1,2)])
print(k)
z=["Jane", "Adam", "Ryan", "Bob", "Zordon", "Jack", "Jackenzie"]
z.sort()
print(z)
# Out:
# [-1, True, 'yes']
# [-1, True, 'yes', 9.0, (1+2j)]
# ['Adam', 'Bob', 'Jack', 'Jackenzie', 'Jane', 'Ryan', 'Zordon']

# %%
#Sequence Types
#Tuples
print("Tuples are similar to lists with the only difference that tuples are immutable. So they can't be changed later.\nHence, tuples also consume less memory than lists since it is known that a tuple will not change.")
print(f'''Tuples are constructed using paranthesis. E.g. x=(1,3,2) is a tuple.
To define a tuple with only one element, y=(1,)''')
x=(1,3,2)
y=(1,)
print(x, y)
print(type(x))

#Checking multiple types at once using isinstance.

print(isinstance(x,(tuple, str, list)))

#using "tuple" to change other sequence objects into tuples. Same is possible for strings and lists
a = [1,2,3,"abc", True]
b=tuple(a)
print(a, b)
# Out:
# Tuples are similar to lists with the only difference that tuples are immutable. So they can't be changed later.
# Hence, tuples also consume less memory than lists since it is known that a tuple will not change.
# Tuples are constructed using paranthesis. E.g. x=(1,3,2) is a tuple.
# To define a tuple with only one element, y=(1,)
# (1, 3, 2) (1,)
# <class 'tuple'>
# True
# [1, 2, 3, 'abc', True] (1, 2, 3, 'abc', True)

# %%
#Common interfaces shared by Python's sequence types.
#1. Checking if an object is a member of the sequence. 
x=(1,3,5)
print(1 in x)
print(5 not in x)
print(7 not in x)

#Strings allow us to check for sub-sequences
print("abc" in "abcdef")
print("cat and mouse" in "cat and mouse are ")

#Other sequences don't allow for checking sub-sequences
print([1,3,5] in [1,3,5,2,1,6])
print('''[1,3,5] should be a single member in the list.
for instance, [1,3,5] in [1,[1,3,5],2,1,5] is''')
print([1,3,5] in [1,[1,3,5],2,1,5])

#2. Concatenating sequences: seq1+seq2
print([1,2,3] + [3,2,1])
print('c'+'at')
print((1,3,2) + (1,2,4))

#3. Repeated concatenations
print("cat" *4)
print([1,2,3,1,2,4]*4)
print((1,2,1,2,2)* 5)

#4. Number of members in the sequence
print(len("godasd"))
print(len([1,2,1,2]))

#5. Getting the index of the first occurence of an element
print("catcatcatcatcat".index("atc"))
print("catcat cat abcat".index('a'))
print('''index() will not look within sub-sequences. [1,2,'moo'].index('m') will not return any index since the element in the list is the string "moo" and not 'm', 'o', 'o'. Uncomment below line to check.''')
#print([1,2,"moo"].index('m'))

#6. Counting the number of occurences
print( "the cat in the hat".count("h"))
print("Similar to index(), count() also doesn't look within sub-sequences")
print([1,2,"moo"].count('m'))

print(tuple([True,None,22]))
# Out:
# True
# False
# True
# True
# True
# False
# [1,3,5] should be a single member in the list.
# for instance, [1,3,5] in [1,[1,3,5],2,1,5] is
# True
# [1, 2, 3, 3, 2, 1]
# cat
# (1, 3, 2, 1, 2, 4)
# catcatcatcat
# [1, 2, 3, 1, 2, 4, 1, 2, 3, 1, 2, 4, 1, 2, 3, 1, 2, 4, 1, 2, 3, 1, 2, 4]
# (1, 2, 1, 2, 2, 1, 2, 1, 2, 2, 1, 2, 1, 2, 2, 1, 2, 1, 2, 2, 1, 2, 1, 2, 2)
# 6
# 4
# 1
# 1
# index() will not look within sub-sequences. [1,2,'moo'].index('m') will not return any index since the element in the list is the string "moo" and not 'm', 'o', 'o'. Uncomment below line to check.
# 3
# Similar to index(), count() also doesn't look within sub-sequences
# 0
# (True, None, 22)

# %% [markdown]
# <div class="alert alert-info">
#
# **Reading Comprehension: Basics of sequences**
#
# 1\. Change the list `[True, None, 22]` into a tuple.
#
# 2\. How many sequence-types have we discussed thus far? Which of these produce objects that are immutable? Which of these produce objects that are mutable? For those types that are mutable, write a piece of example code that mutates an object.
#
# </div>

# %%
print(tuple([True,None,22]))
print("lists are mutable. Strings and Tuples are immutable.")
a=[1,2,[1,2,3],5]
a[0]=True
print(a)
# Out:
# (True, None, 22)
# lists are mutable. Strings and Tuples are immutable.
# [True, 2, [1, 2, 3], 5]

# %% [markdown]
# ### Slicing
# Slicing a sequence allows us to retrieve a subsequence of items, based on the indexing scheme that we reviewed in the preceeding subsection. Specifying a slice consists of:
#
# - A start-index: the sequence-position where the slice begins (this item is *included* in the slice).
# - A stop-index: the sequence-position where the slice ends (this item is *excluded* from the slice).
# - A step-size, which permits us to take every item within the start & stop bounds, or every *other* item, and so on. It is important to note that a negative step-size permits us to traverse a sequence *in reveresed order*.
#
#
#
# Slicing provides sensible default start, stop, and step values. Their default values are:
#
# - start: 0
# - stop: `len(seq)`
# - step: 1
#
# You can omit any of these values or specify `None` in that entry to use the default value. You can omit the second colon entirely, and the slice will use a step-size of 1.

# %%
#Indexing and Slicing
#Slicing
print("Basic Syntax: seq[start:stop:step]")
a="abcsdlhasdhel"
print(a[0:4:1])
print("The step value of 2 means every other element will be fetched between start and stop index:",a[1:5:2])

b='aksdksdjvh'
print(b[:])
print(b[::3])

#Using Negative values in slicing
print("Using negative values for start and stop will slice taking indices in the reverse order. Like:", b[-5:-3])
print("using negative value for the step-size will instruct the slice to traverse in the reverse order", b[::-2])

#Using the built-in slice object in Python. The commonly used syntax mentioned above is a shorthand for the slice object
c='ashd308asldh'
print(c[slice(0,5,2)], c[slice(None,None,-1)])


#The built-in slice object can be assigned to a variable.
#This way we can store a slicing pattern in a variable and use that pattern on multiple sequences without having to define the slicing logic repeatedly

reverseSlice=slice(None,None,-1)
alternateSlice=slice(None, None, 2)

a1=[1,2,[1,2,3],9,'asdhasd']
a2=('aksjdhk',23,5,1,0)
a3='sldhfkjhfkjsd'

print("The reverse slices of the above sequences: ",a1[reverseSlice], a2[reverseSlice], a3[reverseSlice])
print("Alternate slices for the above sequences are:", a1[alternateSlice], a2[alternateSlice], a3[alternateSlice])
# Out:
# Basic Syntax: seq[start:stop:step]
# abcs
# The step value of 2 means every other element will be fetched between start and stop index: bs
# aksdksdjvh
# addh
# Using negative values for start and stop will slice taking indices in the reverse order. Like: sd
# using negative value for the step-size will instruct the slice to traverse in the reverse order hjsdk
# ah3 hdlsa803dhsa
# The reverse slices of the above sequences:  ['asdhasd', 9, [1, 2, 3], 2, 1] (0, 1, 5, 23, 'aksjdhk') dsjkfhjkfhdls
# Alternate slices for the above sequences are: [1, [1, 2, 3], 'asdhasd'] ('aksjdhk', 5, 0) sdfjfjd

# %% [markdown]
# <div class="alert alert-info">
#
# **Reading Comprehension: Indexing and Slicing Sequences**
#
# In Python, a **sequence** is any ordered collection of objects whose contents can be accessed via "indexing". A sub-sequence can be accessed by "slicing" the sequence. You saw, in the required reading, that Python's lists and strings are both examples of sequences. The following questions will help you explore the power of sequence indexing and slicing.
#
# Given the tuple:
# ```python
# x = (0, 2, 4, 6, 8)
# ```
# Slice or index into `x` to produce the following:
#
# 1. `0`
# 2. `8` (using a negative index)
# 3. `(2, 4, 6)` (using a slice-object)
# 4. `(4,)`
# 5. `4`
# 6. `4` (using a negative index)
# 7. `(6, 8)` (using a negative index for the start of the slice)
# 8. `(2, 6)`
# 9. `(8, 6, 4, 2)`
#
# </div>

# %%
x=(0,2,4,6,8)
print(x[0])
print(x[-1])
print(x[1:4])
print(x[2:3])
print(x[2])
print(x[-3])
print(x[-2:])
print(x[1:4:2])
print(x[-1:-5:-1])
# Out:
# 0
# 8
# (2, 4, 6)
# (4,)
# 4
# 4
# (6, 8)
# (2, 6)
# (8, 6, 4, 2)

# %% [markdown]
# <div class="alert alert-info">
#
# **Reading Comprehension: Does slicing a list produce a reference to that list?**
#
# Suppose `x` is assigned a list, and that `y` is assigned a "slice" of `x`. Do `x` and `y` reference the same list? That is, if you update part of the subsequence common to `x` and `y`, does that change show up in both of them? Write some simple code to investigate this.
#
# </div>

# %%
#Variables and Assignments
x=[1,2,3,1]
y=x[0:2]
x[0]=0
print(x)
print(y)
# Out:
# [0, 2, 3, 1]
# [1, 2]

# %%
#Conditional Statements
#Comparison Operators
print("Difference b/w '==' and 'is': == compares the values of two objects and 'is' checks if the objects are actually the same objects")
x = None
print(x is None)
x=[1,2,3]
y=[1,2,3]

print(x==y)
print(x is y)
y=x
print(x is y)
# Out:
# Difference b/w '==' and 'is': == compares the values of two objects and 'is' checks if the objects are actually the same objects
# True
# True
# False
# True

# %% [markdown]
# ## `bool` and Truth Values of Non-Boolean Objects
# Python ascribes boolean values to non-boolean objects. For example,the number 0 is associated with `False` and non-zero numbers are associated with `True`. The boolean values of built-in objects can be evaluated with the built-in Python command `bool`:
#
# ```python
# # Using `bool` to access the True/False
# # value of non-boolean objects
# >>> bool(0)
# False
# ```
#
# and non-zero Python integers are associated with `True`:
#
# ```python
# # nonzero values evaluate to `True`
# >>> bool(2)
# True
# ```
# The following built-in Python objects evaluate to `False` via `bool`:
#
# - `False`
# - `None`
# - Zero of any numeric type: `0`, `0.0`, `0j`
# - Any empty sequence, such as an empty string or list: `''`, `tuple()`, `[]`, `numpy.array([])`
# - Empty dictionaries and sets
#
# Thus non-zero numbers and non-empty sequences/collections evaluate to `True` via `bool`.
#
# <div class="alert alert-info">
#
# **Takeaway**:
#
# The `bool` function allows you to evaluate the boolean values ascribed to various non-boolean objects. For instance, `bool([])` returns `False` wherease `bool([1, 2])` returns `True`.
# </div>

# %%
print(f'''Just like boolean values True and False are associated with integer values 1 and 0, Python associates boolean values to non-boolean objects.
All non zero numbers and non empty sequences evaluate True.''')
print(bool([1,2,3,]))
print(bool([]))
print(bool(1))
# Out:
# Just like boolean values True and False are associated with integer values 1 and 0, Python associates boolean values to non-boolean objects.
# All non zero numbers and non empty sequences evaluate True.
# True
# False
# True

# %% [markdown]
# ## `if`, `else`, and `elif`
#
# ```python
# if <expression_1>:
#     the code within this indented block is executed if..
#     - bool(<expression_1>) is True
# elif <expression_2>:
#     the code within this indented block is executed if..
#      - bool(<expression_1>) was False
#      - bool(<expression_2>) is True
# ...
# ...
# elif <expression_n>:
#     the code within this indented block is executed if..
#       - bool(<expression_1>) was False
#       - bool(<expression_2>) was False
#       ...
#       ...
#       - bool(<expression_n-1>) was False
#       - bool(<expression_n>) is True
# else:
#     the code within this indented block is executed only if
#     all preceding expressions were False
# ```
#
# Each `if`, `elif`, and `else` statement must end in a colon character, and the body of each of these statements is [delimited by whitespace]
#
# In its simplest form, a conditional statement requires only an `if` clause. `else` and `elif` clauses can only follow an `if` clause.
#
# ```python
# # A conditional statement consisting of
# # an "if"-clause, only.
#
# x = -1
#
# if x < 0:
#     x = x ** 2
# # x is now 1
# ```
#
# Similarly, conditional statements can have an `if` and an `else` without an `elif`:
#
# ```python
# # A conditional statement consisting of
# # an "if"-clause and an "else"
# x = 4
#
# if x > 2:
#     x = -2
# else:
#     x = x + 1
# # x is now -2
# ```
#
# Conditional statements can also have an `if` and an `elif` without an `else`:
#
# ```python
# # A conditional statement consisting of
# # an "if"-clause and an "elif"
# x = 'abc'
#
# if len(x) < 9:
#     x = x * 3
# elif len(x) > 40:
#     x = 'cba'
# # x is now 'abcabcabc'
# ```
#
# Note that only one code block within a single if-elif-else statement can be executed: either the "if-block" is executed, or an "elif-block" is executed, or the "else-block" is executed. Consecutive if-statements, however, are completely independent of one another, and thus their code blocks can be executed in sequence, if their respective conditional statements resolve to `True`.
#
# ```python
# # consecutive if-statements are independent
# x = 5
# y = 0
#
# if x < 10:
#     y += 1
#
# if x < 20:
#     y += 1
#
# # y is now 2
# ```
#
# <div class="alert alert-info">
#
# **Reading Comprehension: Conditional statements**
#
# 1\. Assume `my_list` is a list. Given the following code:
# ```python
# first_item = None
#
# if my_list:
#     first_item = my_list[0]
# ```
#
# What will happen if `my_list` is `[]`? Will `IndexError` be raised? What will `first_item` be?
#
# 2\. Assume variable `my_file` is a string storing a filename, where a period denotes the end of the filename and the beginning of the file-type. Write code that extracts only the filename.
#
# `my_file` will have at most one period in it. Accommodate cases where `my_file` does *not* include a file-type.
#
# That is:
#
# - `"code.py"` $\rightarrow$ `"code"`
# - `"doc2.pdf"` $\rightarrow$ `"doc2"`
# - `"hello_world"` $\rightarrow$ `"hello_world"`
#
# </div>

# %%
my_file='code.py'
# my_file='doc2.pdf'
# my_file='hello_world'
if('.' in my_file):
    period=my_file.index('.')
    my_file=my_file[:period]
print(my_file)
# Out:
# code

# %% [markdown]
# ### Inline if-else statements
# Python supports a syntax for writing a restricted version of if-else statements in a single line. The following code:
#
# ```python
# num = 2
#
# if num >= 0:
#     sign = "positive"
# else:
#     sign = "negative"
# ```
#
# can be written in a single line as:
#
# ```python
# sign = "positive" if num >=0 else "negative"
# ```
#
# <div class="alert alert-info">
#
# **The inline if-else statement**:
#
# The expression `A if <condition> else B` returns `A` if `bool(<condition>)` evaluates to `True`, otherwise this expression will return `B`.
# </div>
#
# This syntax is highly restricted compared to the full "if-elif-else" expressions - no "elif" statement is permitted by this inline syntax, nor are multi-line code blocks within the if/else clauses.
#
# ```python
# # using inline if-else statements in different scenarios
#
# >>> x = 2
#
# # will store 1 if `x` is non-negative
# # will store 0 if `x` is negative
# >>> my_list = [1 if x >= 0 else 0]
# >>> my_list
# [1]
#
# >>> "a" if x == 1 else "b"
# 'b'
# ```
# ```python
# # don't ever do this...ever!
# 2 - 3 if x < 1 else 1 + 6*2 if x >= 0 else 9
# ```

# %% [markdown]
# ## Short-Circuiting Logical Expressions
#
# consider the fact that an `and` operation will only return `True` if both of its arguments evaluate to `True`. Thus the expression `False and <anything>` is guaranteed to return `False`; furthermore, when executed, this expression will return `False` *without having evaluated* `bool(<anything>)`.
#
# ```python
# # demonstrating short-circuited logic expressions
# >>> False and 1/0  # evaluating `1/0` would raise an error
# False
# ```
# According to our discussion, the pattern `False and` short-circuits this expression without it ever evaluating `bool(1/0)`. Reversing the ordering of the arguments makes this clear.
#
# ```python
# # expressions are evaluated from left to right
# >>> 1/0 and False
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-3471672109ee> in <module>()
# ----> 1 1/0 and False
#
# ZeroDivisionError: division by zero
# ```
#
# In practice, short-circuiting can be leveraged in order to condense one's code. Suppose a section of our code is processing a variable `x`, which may be either a [number](https://www.pythonlikeyoumeanit.com/Module2_EssentialsOfPython/Basic_Objects.html#Number-Types) or a [string](https://www.pythonlikeyoumeanit.com/Module2_EssentialsOfPython/Basic_Objects.html#Strings). Suppose further that we want to process `x` in a special way if it is an all-uppercased string. The code
#
# ```python
# # this will raise an error if `x` is not a string
# if x.isupper():
#     # do something with the uppercased string
# ```
# is problematic because `isupper` can only be called once we are sure that `x` is a string; this code will raise an error if `x` is a number. We could instead write
#
# ```python
# # a valid but messy way to filter out non-string objects
# if isinstance(x, str):
#     if x.isupper():
#         # do something with the uppercased string
# ```
#
# but the more elegant and concise way of handling the nestled checking is to leverage our ability to short-circuit logic expressions.
#
# ```python
# # utilizing short-circuiting to concisely perform all necessary checks
# if isinstance(x, str) and x.isupper():
#     # do something with the uppercased string
# ```
#
# See, that if `x` is not a string, that `isinstance(x, str)` will return `False`; thus `isinstance(x, str) and x.isupper()` will short-circuit and return `False` without ever evaluating `bool(x.isupper())`. This is the preferable way to handle this sort of checking. This code is more concise and readable than the equivalent nested if-statements.

# %%
x=12
x='ASD'
if isinstance(x,str) and x.isupper():
    print('yes')
# Out:
# yes

# %% [markdown]
# ## For-Loops
# The general syntax for a "for-loop" is:
#
# ```
# for <var> in <iterable>:
#     block of code
# ```
#
# Where `<var>` is any valid variable-identifier and `<iterable>` is any **iterable**.
#
# The for-loop behaves as follows:
#
# - Request the next member of the iterable.
# - If the iterable is empty, exit the for-loop without running its body.
# - If the iterable did produce a member, assign that member to `<var>` (if `<var>` was not previously defined, it becomes defined).
# - Execute the enclosed body of code.
# - Go back to the first step.

# %%
#For Loops

print('''Note that when iterating over an empty iterable, the for loop will exit before 
the <var> variable is even defined. Accessing <var> in such cases will raise NameError.
Hence, our code should not be dependent on the <var> outside the for-loop''')

for a in 'abcdefghij':
    if a in 'aeiou':
        print(a)
# Out:
# Note that when iterating over an empty iterable, the for loop will exit before
# the <var> variable is even defined. Accessing <var> in such cases will raise NameError.
# Hence, our code should not be dependent on the <var> outside the for-loop
# a
# e
# i

# %% [markdown]
# ## While-Loops
# A "while-loop" allows you to repeat a block of code until a condition is no longer true:
#
# ```
# while <condition>:
#     block of code
# ```
#
# Where `<condition>` is an expression that returns `True` or `False`, or is any object on which `bool` can be called. The "body" of the while-loop is the code indented beneath the while-loop statement.
#
# <div class="alert alert-info">
#
# **Reading Comprehension: A basic while-loop**
#
# Given a list of nonzero, positive numbers, `x`, append the sum of that list to the end of it. Do this until the last value in `x` is at least 100. Use a while-loop.
#
# If you start with `x = [1]`, then by the end of your while-loop `x` should be `[1, 1, 2, 4, 8, 16, 32, 64, 128]`.
#
# </div>

# %%
x=[1]
while len(x) <2 or not(x[-2] < 100 and x[-1] >=100):
    x.append(sum(x))
print(x)
# Out:
# [1, 1, 2, 4, 8, 16, 32, 64, 128]

# %% [markdown]
# ## `break`, `continue`, & `else` clauses on loops
# The `continue` and `break` statements can be used within the bodies of both for-loops and while-loops. They provide added means for "short-circuiting" or prematurely exiting a given loop, respectively.
#
# Break: encountering break statement in the loop will cause the loop to exited immediately.
#
# Continue: encountering continue statement in the loop will cause the loop to be revisited immediately to the next iteration, without executing any code written in the loop after the continue statement.
#
# ```ipython
# # breaking out of a loop early
# >>> for item in [1, 2, 3, 4, 5]:
# ...     if item == 3:
# ...         print(item, " ...break!")
# ...         break
# ...     print(item, " ...next iteration")
# ```
# ```
# 1  ...next iteration
# 2  ...next iteration
# 3  ...break!
# ```
#
# An `else` clause can be added to the end of any loop. The body of this else-statement will be executed *only if the loop was not exited via a `break` statement*.
#
# ```ipython
# # including an else-clause at the end of the loop
# >>> for item in [2, 4, 6]:
# ...     if item == 3:
# ...         print(item, " ...break!")
# ...         break
# ...     print(item, " ...next iteration")
# ... else:
# ...     print("if you are reading this, then the loop completed without a 'break'")
# ```
# ```
# 2  ...next iteration
# 4  ...next iteration
# 6  ...next iteration
# if you are reading this, then the loop completed without a 'break'
# ```
# ```python
# # demonstrating a `continue` statement in a loop
# >>> x = 1
# >>> while x < 4:
# ...     print("x = ", x, ">> enter loop-body <<")
# ...     if x == 2:
# ...         print("x = ", x, " continue...back to the top of the loop!")
# ...         x += 1
# ...         continue
# ...     x += 1
# ...     print("--reached end of loop-body--")
# ```
# ```
# x =  1 >> enter loop-body <<
# --reached end of loop-body--
# x =  2 >> enter loop-body <<
# x =  2  continue...back to the top of the loop!
# x =  3 >> enter loop-body <<
# --reached end of loop-body--
# ```
#
# <div class="alert alert-info">
#
# **Reading Comprehension: conducting flow in a loop**
#
# Loop over a list of integers repeatedly, summing up all of its even values, and adding the content to a total. Repeat this process until the the total exceeds 100, or if you have looped over the list more than 50 times. Print the total only if it exceeds 100.
#
# </div>

# %%
x = [3, 4, 1, 2, 8, 10, -3, 0]

total=0
i=0
while total <= 100:
    for item in x:
        if item % 2 == 0:
            total+=item
    i+=1
    if i == 51:
        break
else:
    print(total)
# Out:
# 120

# %% [markdown]
# # Iterables
# Our encounter with for-loops introduced the term *iterable* - an object that can be "iterated over", such as in a for-loop.
#
# <div class="alert alert-info">
#
# **Definition**:
#
# An **iterable** is any Python object capable of returning its members one at a time, permitting it to be iterated over in a for-loop.
# </div>
#
# Familiar examples of iterables include lists, tuples, and strings - any such sequence can be iterated over in a for-loop. We will also encounter important non-sequential collections, like dictionaries and sets; these are iterables as well. It is also possible to have an iterable that "generates" each one of its members upon iteration - meaning that it doesn't ever store all of its members in memory at once. We dedicate an entire section to generators, a special type of iterator, because they are so useful for writing efficient code.
#
# The rest of this section is dedicated to working with iterables in your code.
#
# <div class="alert alert-warning">
#
# **Note**:
#
# "Under the hood", an iterable is any Python object with an `__iter__()` method or with a `__getitem__()` method that implements `Sequence` semantics. These details will become salient if you read through the Object Oriented Programming module.
# </div>
#
# ## Functions that act on iterables
# Here are some useful built-in functions that accept iterables as arguments:
#
#  - `list`, `tuple`, `dict`, `set`: construct a list, tuple, [dictionary](https://www.pythonlikeyoumeanit.com/Module2_EssentialsOfPython/DataStructures_II_Dictionaries.html), or [set](https://www.pythonlikeyoumeanit.com/Module2_EssentialsOfPython/DataStructures_III_Sets_and_More.html#The-%E2%80%9CSet%E2%80%9D-Data-Structure), respectively, from the contents of an iterable
#  - `sum`: sum the contents of an iterable.
#  - `sorted`: return a list of the sorted contents of an interable
#  - `any`: returns `True` and ends the iteration immediately if `bool(item)` was `True` for *any* item in the iterable.
#  - `all`: returns `True` only if `bool(item)` was `True` for *all* items in the iterable.
#  - `max`: return the largest value in an iterable.
#  - `min`: return the smallest value in an iterable.
#
# ```python
# # Examples of built-in functions that act on iterables
# >>> list("I am a cow")
# ['I', ' ', 'a', 'm', ' ', 'a', ' ', 'c', 'o', 'w']
#
# >>> sum([1, 2, 3])
# 6
#
# >>> sorted("gheliabciou")
# ['a', 'b', 'c', 'e', 'g', 'h', 'i', 'i', 'l', 'o', 'u']
#
# # `bool(item)` evaluates to `False` for each of these items
# >>> any((0, None, [], 0))
# False
#
# # `bool(item)` evaluates to  `True` for each of these items
# >>> all([1, (0, 1), True, "hi"])
# True
#
# >>> max((5, 8, 9, 0))
# 9
#
# >>> min("hello")
# 'e'
# ```

# %%
#Using iterable built-in functions
x=[1,2,3,1,13,41,1,4]
print(f'the sum of {x} is {sum(x)}')
print(f'sorted {x} is {sorted(x)}')
print(f'''\nthe built in any() function returns True and ends the iteration immediately if bool(item) is True for any item in the iterable. 
Recall boolean values for non booleans objects section. Any empty item or item with value 0 of any kind will return bool(item) as False. here, any(x) is {any(x)}''')
print(f'''\nThe built in all() function will return True only if for all the items in the iterable, bool(item) return True
here, all(x) is {all(x)}''')
print(f'\nThe built-in funcion max() return the largest value in the iterable. Here, max(x) is {max(x)}')
print(f'\nThe built-in funcion min() return the largest value in the iterable. Here, min(x) is {min(x)}')
# Out:
# the sum of [1, 2, 3, 1, 13, 41, 1, 4] is 66
# sorted [1, 2, 3, 1, 13, 41, 1, 4] is [1, 1, 1, 2, 3, 4, 13, 41]
#
# the built in any() function returns True and ends the iteration immediately if bool(item) is True for any item in the iterable.
# Recall boolean values for non booleans objects section. Any empty item or item with value 0 of any kind will return bool(item) as False. here, any(x) is True
#
# The built in all() function will return True only if for all the items in the iterable, bool(item) return True
# here, all(x) is True
#
# The built-in funcion max() return the largest value in the iterable. Here, max(x) is 41
#
# The built-in funcion min() return the largest value in the iterable. Here, min(x) is 1

# %% [markdown]
# ### "Unpacking" iterables
# Suppose that you have three values stored in a list, and that you want to assign each value to a distinct variable. Given the lessons that we have covered thus far, you would likely write the following code:
#
# ```python
# # simple script for assigning contents of a list to variables
# >>> my_list = [7, 9, 11]
#
# >>> x = my_list[0]
# >>> y = my_list[1]
# >>> z = my_list[2]
# ```
#
# Python provides an extremely useful functionality, known as **iterable unpacking**, which allows us to write the simple, elegant code:
#
# ```python
# # assigning contents of a list to variables using iterable unpacking
# >>> my_list = [7, 9, 11]
#
# >>> x, y, z = my_list
# >>> print(x, y, z)
# 7 9 11
# ```
#
# That is, the Python interpreter "sees" the pattern of variables to the left of the assignment, and will "unpack" the iterable (which happens to be a list in this instance).
#
# Iterable unpacking is particularly useful in the context of performing for-loops over iterables-of-iterables. For example, suppose we have a list containing tuples of name-grade pairs:
#
# ```python
# >>> grades = [("Ashley", 93), ("Brad", 95), ("Cassie", 84)]
# ```
#
# Recall from the preceding section that if we loop over this list, that the iterate-variable will be assigned to each of these tuples:
#
# ```python
# for entry in grades:
#     print(entry)
# ```
# will print:
# ```
# ('Ashley', 93)
# ('Brad', 95)
# ('Cassie', 84)
# ```
#
# It is likely that we will want to work with the student's name and their grade independently (e.g. use the name to access a log, and add the grade-value to our class statistics); thus we will need to index into `entry` twice to assign its contents to two separate variables. However, because each iteration of the for-loop involves an assignment of the form `entry = ("Ashley", 93)`, we can make use of iterable unpacking! That is, we can replace `entry` with `name, grade` and Python will intuitively do an unpacking upon each assignment of the for-loop.
#
# ```python
# # The first iteration of this for-loop performs
# # the unpacking assignment: name, grade = ("Ashley", 93)
# # then the second iteration: name, grade = ("Brad", 95)
# # and so-on
# for name, grade in grades:
#     print(name)
#     print(grade)
#     print("\n")
# ```
# prints:
# ```
# Ashley
# 93
#
# Brad
# 95
#
# Cassie
# 84
# ```

# %%
#Unpacking
print(f'''Python allows iterable "unpacking" which is to assign a variable to each item in the iterable.
This allows us to avoid repeated variable assignments for the items in an iterable.
Also, this is helpful when iterating over iterables of iterables, e.g., x=[(1,2),(2,4),(3,1)] is a list of tuples having 2 items.
Iterating over x in a for loop will allow us to store both the items of the tuples in different variables.''')
#Using Unpacking syntax
x=[1,2,3]
a,b,c=x
print('\n',a,b,c)

x=[(1,2),(2,4),(3,1)]
for item in x:
    print(item)
for a,b in x:
    print(a)
    print(b)
print("\nHaving more values in the iterable than the variables will throw too many values to unpack error.")
# x=[1,2,1,2,3,1,1,2,3,1,3,4,5,1,5]
# a,b=x
# print(a,b)
# Out:
# Python allows iterable "unpacking" which is to assign a variable to each item in the iterable.
# This allows us to avoid repeated variable assignments for the items in an iterable.
# Also, this is helpful when iterating over iterables of iterables, e.g., x=[(1,2),(2,4),(3,1)] is a list of tuples having 2 items.
# Iterating over x in a for loop will allow us to store both the items of the tuples in different variables.
#
#  1 2 3
# (1, 2)
# (2, 4)
# (3, 1)
# 1
# 2
# 2
# 4
# 3
# 1
#
# Having more values in the iterable than the variables will throw too many values to unpack error.

# %% [markdown]
# ### Enumerating iterables
# The built-in [enumerate](https://docs.python.org/3/library/functions.html#enumerate) function allows us to iterate over an iterable, while keeping track of the iteration count:
#
# ```python
# # basic usage of `enumerate`
# >>> for entry in enumerate("abcd"):
# ...    print(entry)
# (0, 'a')
# (1, 'b')
# (2, 'c')
# (3, 'd')
# ```
#
# In general, the `enumerate` function accepts an iterable as an input, and returns a new iterable that produces a tuple of the iteration-count and the corresponding item from the original iterable.
# Thus the items in the iterable are being enumerated. To see the utility of this, suppose that we want to record all of the positions in a list where the value `None` is stored. We can achieve this by tracking the iteration count of a for-loop over the list.
#
# ```python
# # track which entries of an iterable store the value `None`
# none_indices = []
# iter_cnt = 0  # manually track iteration-count
#
# for item in [2, None, -10, None, 4, 8]:
#     if item is None:
#         none_indices.append(iter_cnt)
#     iter_cnt = iter_cnt + 1
#
# # `none_indices` now stores: [1, 3]
# ```
#
# We can simplify this code, and avoid having to initialize or increment the `iter_cnt` variable, by utilizing `enumerate` along with tuple-unpacking.
#
# ```python
# # using the `enumerate` function to keep iteration-count
# none_indices = []
#
# # note the use of iterable unpacking!
# for iter_cnt, item in enumerate([2, None, -10, None, 4, 8]):
#     if item is None:
#         none_indices.append(iter_cnt)
#
# # `none_indices` now stores: [1, 3]
# ```
#
# <div class="alert alert-info">
# **Takeaway**:
#
# Python provides a sleek syntax for "unpacking" the contents of an iterable - assigning each item to its own variable. This allows us to write intuitive, highly-readable code when performing a for-loop over a collection of iterables.
#
# The built-in [enumerate](https://docs.python.org/3/library/functions.html#enumerate) function should be used (in conjunction with iterator unpacking) whenever it is necessary to track the iteration count of a for-loop. It is valuable to use this in conjunction with tuple unpacking.
# </div>

# %%
#Enumerating iterables
print(f'Enumerate allows us to iterate over any iterable and also keep a track of the iteration count. \nThe built-in enumerate() function takes any iterable as input and returns a new iterable of tuples containing the iteration counter and the original iterable item')
print(f'\nWe have a list [(1,2), (4,5), 8, 9] and we use a for loop to iterate over resultant iterable after using enumerate() over this list. ')
for entry in enumerate([(1,2), (4,5), 8, 9]):
    print(entry)
print(f'Using enumerate to find all the entries in the iterable [2, None, -10, None, 4, 8]) storing None:')
None_indices=[]
for i,item in enumerate([2, None, -10, None, 4, 8]):
    print(i,item)
    if item is None:
        None_indices.append(i)
print(None_indices)
# Out:
# Enumerate allows us to iterate over any iterable and also keep a track of the iteration count.
# The built-in enumerate() function takes any iterable as input and returns a new iterable of tuples containing the iteration counter and the original iterable item
#
# We have a list [(1,2), (4,5), 8, 9] and we use a for loop to iterate over resultant iterable after using enumerate() over this list.
# (0, (1, 2))
# (1, (4, 5))
# (2, 8)
# (3, 9)
# Using enumerate to find all the entries in the iterable [2, None, -10, None, 4, 8]) storing None:
# 0 2
# 1 None
# 2 -10
# 3 None
# 4 4
# 5 8
# [1, 3]

# %% [markdown]
# <div class="alert alert-info">
#
# **Reading Comprehension: enumerate**
#
# Use the iterable `"abcd"`, the `enumerate` function, and tuple-unpacking in a for-loop to create the list: `[(0, 'a'), (1, 'b'), (2, 'c'), (3, 'd')]`
#
# **Reading Comprehension: Is it sorted?**
#
# Use control flow and looping tools to see if an iterable of numbers is sorted.
#
# The variable `unsorted_index` should be initialized to `None`. If the iterable is *not* sorted, `unsorted_index` should store the index where the sequence *first* fell out of order. If the iterable is sorted, then `unsorted_index` should remain `None` and your code should print "sorted!".
#
# For instance:
#
#  - given the iterable `my_list = [0, 1, -10, 2]`, `unsorted_index` should take the value `2`.
#  - given the iterable `my_list = [-1, 0, 3, 6]`, `unsorted_index` should be `None` and your code should print "sorted!".
#
# </div>

# %%
NewList1=[]
for i,item in enumerate('abcd'):
    NewList1.append((i,item))
print(NewList1)
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c'), (3, 'd')]
